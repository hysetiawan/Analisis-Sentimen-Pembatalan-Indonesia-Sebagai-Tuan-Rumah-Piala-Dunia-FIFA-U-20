# %%
# !pip install snscrape
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
from textblob import TextBlob
import re
def clean_tweet(tweet):
  return ' '.join(re.sub("(@[A-Za-z0-9]+) | (@[^0-9A-Za-z \t]) | (/w+:\/\/\S+)", " ", tweet).split())
#Sentimen analsis dengan polarity menggunakan library textblob
def analize_sentiment(tweet):
  analysis = TextBlob (clean_tweet(tweet))
  if analysis.sentiment.polarity > 0:
    return 1
  elif analysis.sentiment.polarity == 0:
    return 0
  else :
    return -1
  def analize_subjectorobject(tweet):
    #Kita dapat melihat polaritas [-1][0][1] untuk -1 termasuk negatif, 0 netral dan 1 positif.
    #Misal terdapat polarity 0.8 yang berarti pernyataan positif dan subjektifitas 0.75 merujuk bahwa itu adalah opini publik dan bukan informasi faktual
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
      return "Positif"
    elif analysis.sentiment.polarity == 0:
      return "Netral"
    else:
      return "Negatif"

# %%
# buat daftar untuk menambah data dari twitter
tweets_list = []

# %%
#buat TwiterSearcScrapper untuk mengambil data
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('fifa batal u-20 since:2023-03-25 until:2023-03-30').get_items()):
  if i>20000:
    break
  tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username, analize_sentiment(tweet.content)])
# Out:
# <ipython-input-39-b550d5be4ed1>:5: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username, analize_sentiment(tweet.content)])

# %%
# membuat tabel dari data tweet yang sudah di ambil
tweet = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Tweet', 'Username', 'Label'])

# %%
tweet
# Out:
#                      Datetime             Tweet Id  \
# 0   2023-03-29 23:54:18+00:00  1641227310878818305
# 1   2023-03-29 23:50:40+00:00  1641226398424612866
# 2   2023-03-29 23:49:42+00:00  1641226154354053121
# 3   2023-03-29 23:45:59+00:00  1641225217765969920
# 4   2023-03-29 23:43:24+00:00  1641224569670467584
# ..                        ...                  ...
# 941 2023-03-25 04:50:07+00:00  1639489820019011584
# 942 2023-03-25 04:50:06+00:00  1639489812297318401
# 943 2023-03-25 04:50:00+00:00  1639489787324186626
# 944 2023-03-25 04:50:00+00:00  1639489787206971392
# 945 2023-03-25 01:09:13+00:00  1639434226423717897
#
#                                                  Tweet     Username  Label
# 0    Potential sanctions against the PSSI may also ...         wdtu      1
# 1    FIFA: Indonesia Batal Jadi Tuan Rumah Piala Du...     ChoNunik      0
# 2    Wah wah wah, FIFA World Cup U-20 batal di Indo...    newrosita      0
# ...

# %%
tweet.groupby('Label').describe()
# Out:
#       Tweet Id                                                          \
#          count          mean           std           min           25%
# Label
# -1        18.0  1.640701e+18  3.989152e+14  1.640117e+18  1.640307e+18
#  0       885.0  1.640613e+18  4.746051e+14  1.639434e+18  1.640270e+18
#  1        43.0  1.640702e+18  4.764373e+14  1.639496e+18  1.640293e+18
#
#
#                 50%           75%           max
# Label
# -1     1.640647e+18  1.641104e+18  1.641207e+18
#  0     1.640568e+18  1.641107e+18  1.641226e+18
#  1     1.640706e+18  1.641115e+18  1.641227e+18

# %%
tweet_positif=tweet[tweet['Label'] > 0]
tweet_positif.head()
# Out:
#                     Datetime             Tweet Id  \
# 0  2023-03-29 23:54:18+00:00  1641227310878818305
# 3  2023-03-29 23:45:59+00:00  1641225217765969920
# 7  2023-03-29 23:25:49+00:00  1641220144021270530
# 25 2023-03-29 22:17:15+00:00  1641202889250189312
# 29 2023-03-29 22:09:34+00:00  1641200957097930753
#
#                                                 Tweet       Username  Label
# 0   Potential sanctions against the PSSI may also ...           wdtu      1
# 3   Media Sosial\n\nPro (27%):\n• Minta warganet p...    ismailfahmi      1
# 7   Skenarionya gini\n-Argentina gagal lolos Piala...    Rahman12996      1
# 25  Sangat disayangkan akhirnya Pildun U-20 batal,...      FardaniYS      1
# 29  Batal jadi tuan rumah Piala Dunia U-20, apa yg...  2karakterbisa      1

# %%
tweet_negatif=tweet[tweet['Label'] < 0]
tweet_negatif.head()
# Out:
#                      Datetime             Tweet Id  \
# 21  2023-03-29 22:34:09+00:00  1641207143201394688
# 134 2023-03-29 17:03:32+00:00  1641123937710129152
# 194 2023-03-29 16:15:49+00:00  1641111930894184449
# 232 2023-03-29 15:59:01+00:00  1641107703627149312
# 254 2023-03-29 15:47:31+00:00  1641104809096007680
#
#                                                  Tweet       Username  Label
# 21   Yah batal...ambil himahnya, minimal menghilang...    patahulla06     -1
# 134  Oke. Keputusan FIFA sudah diambil. Indonesia b...  FahmiAgustian     -1
# 194  Lagunya Tiara, Lyodra, Ziva flat Weird Genius ...      skawngr_j     -1
# 232  Indonesia kocak, PSSI sama aja. Pejabat sibuk ...       ecowskii     -1
# 254  Pildun u-20 batal,. \nSebenarnya banyak Poin d...    ariusmarley     -1

# %%
tweet_netral=tweet[tweet['Label'] == 0]
tweet_netral.head()
# Out:
#                    Datetime             Tweet Id  \
# 1 2023-03-29 23:50:40+00:00  1641226398424612866
# 2 2023-03-29 23:49:42+00:00  1641226154354053121
# 4 2023-03-29 23:43:24+00:00  1641224569670467584
# 5 2023-03-29 23:34:06+00:00  1641222230419083265
# 6 2023-03-29 23:28:48+00:00  1641220894965260288
#
#                                                Tweet        Username  Label
# 1  FIFA: Indonesia Batal Jadi Tuan Rumah Piala Du...        ChoNunik      0
# 2  Wah wah wah, FIFA World Cup U-20 batal di Indo...       newrosita      0
# 4  @ganjarpranowo Tiada hari tanpa pencitraan. \n...       CozyAmos1      0
# 5  Indonesia Batal Tuan Rumah Piala Dunia U-20 ht...     nusabalicom      0
# 6  Tidak ada yang bisa ataupun boleh disalahkan d...  apoy_orasepele      0

# %%
frames = [tweet_positif, tweet_negatif, tweet_netral]
#menghapus duplikasi
hasil = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
hasil.to_csv(r'DataFIFACrawling.csv', index=False)

# %%
hasil.to_excel(r'DataFIFAbanyak.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5a9e305b75b1> in <cell line: 1>()
# ----> 1 hasil.to_excel(r'DataFIFAbanyak.xlsx', index=False)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...
